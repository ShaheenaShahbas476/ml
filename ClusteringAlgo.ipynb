# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Customer dataset
X = np.array([
    [500, 20],
    [1500, 50],
    [700, 30],
    [2000, 70],
    [1000, 40],
    [250, 10],
    [1200, 60],
    [300, 15]
])

# Apply K-Means
kmeans = KMeans(n_clusters=2)
kmeans.fit(X)

# Extract centroids and labels
centroids = kmeans.cluster_centers_
labels = kmeans.labels_

# Plot clusters
plt.scatter(X[:, 0], X[:, 1], c=labels, s=50, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=200, alpha=0.75, marker='X')
plt.xlabel('Annual Spending ($)')
plt.ylabel('Number of Visits')
plt.title('Customer Segmentation (K-Means Clustering)')
plt.show()

# Print cluster assignments
print("Customer Segments (Cluster Assignments):")
for i, label in enumerate(labels):
    print(f"Customer {i+1} belongs to Cluster {label + 1}")
# Out:
# Customer Segments (Cluster Assignments):
# Customer 1 belongs to Cluster 2
# Customer 2 belongs to Cluster 1
# Customer 3 belongs to Cluster 2
# Customer 4 belongs to Cluster 1
# Customer 5 belongs to Cluster 1
# Customer 6 belongs to Cluster 2
# Customer 7 belongs to Cluster 1
# Customer 8 belongs to Cluster 2
